# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
# 1. Use matplotlib to plot the following equation:
# y = x**2 -x + 2

x = list(range(-100,100))
y = [(n**2) - n + 2 for n in x]

# print(y)
# print(x)
fig, ax = plt.subplots()
plt.plot(x,y)
ax.annotate("(0,0)", xy =(10.3, 10),
                xytext =(4, 20), arrowprops ={"arrowstyle": "fancy"}
                )

plt.show()

# %%
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
# y = \sqrt{x}
# y = x^3
# y = 2^x
# y = 1/(x+1)


# You can use functions from the math module to help implement some of the equations above.
# first chart

x = np.array(range(1,20))
y1 = np.sqrt(x)
plt.plot(x,y1)
plt.show()
#second chart
y2 = x**3
plt.plot(x,y2)
plt.show()
# third chart 
y3 = 2**x
plt.plot(x,y3)
plt.show()
# fourth chart
y4 = 1/(x + 1)
plt.plot(x,y4)
plt.show()

# %%
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.
# first chart
x = np.array(range(1,100))
y1 = np.sqrt(x1)
plt.plot(x1,y1)

#second chart
y2 = x**3
plt.plot(x,y2)

# third chart 
y3 = 2**x
plt.plot(x,y3)

# fourth chart
y4 = 1/(x + 1)
plt.plot(x,y4)
plt.show()

# first chart
plt.subplot(2,2,1)
x1 = np.array(range(1,20))
y1 = np.sqrt(x1)
plt.plot(x1,y1)

#second chart
plt.subplot(2,2,2)
y2 = x**3
plt.plot(x,y2)

# third chart 
plt.subplot(2,2,3)
y3 = 2**x
plt.plot(x,y3)

# fourth chart
plt.subplot(2,2,4)
y4 = 1/(x + 1)
plt.plot(x,y4)
plt.show()

# %%
# 1. Combine the figures you created in the last step into one figure 
# where each of the 4 equations has a different color for the points. 
# Be sure to include a legend and an appropriate title for the figure.
x = np.array(range(1,100))
y1 = np.sqrt(x)
y2 = x**3
y3 = 2**x
y4 = 1/(x + 1)

# chart

plt.plot(x,y1, c='b', label="$y = \sqrt{x}$")
plt.plot(x,y2,  c='g', label="$y = x^3$")
plt.plot(x,y3,  c='r', label="$y = 2^x$")
plt.plot(x,y4,  c='indigo', label="$y = 1/(x+1)$")

plt.ylim(-1,8)
plt.xlim(-1,8)
plt.title("Chart of Equations")
plt.legend(loc="upper left")

plt.show()

# %%
# x values
n = np.arange(1,20)

# O(1)
y1 = 0*n + 1

# O(log n)
y2 = np.log(n)

# O(n)
y3 = n

# O(n log n)
y4 = np.log(n) * n

# O(n^2)
y5 = n**2

# O(2^n)
y6 = 2**n

# O(n!)
y7 = [math.factorial(i) for i in n]

# O(n^n)
y8 = n**n

# %%
plt.plot(n, y1, label='$\mathcal{O}(1)$', color='b')
plt.plot(n, y2, label='$\mathcal{O}(logn)$', color='g')
plt.plot(n, y3, label='$\mathcal{O}(n)$', color='y')
plt.plot(n, y4, label='$\mathcal{O}(nlogn)$', color='olive')
plt.plot(n, y5, label='$\mathcal{O}(n^{2})$', color='orange')
plt.plot(n, y6, label='$\mathcal{O}(2^{n})$', color='saddlebrown')
plt.plot(n, y7, label='$\mathcal{O}(n!)$', color='salmon')
plt.plot(n, y8, label='$\mathcal{O}(n^{n})$', color='red')

plt.xlim(1, 11)
plt.ylim(0, 50)

plt.xlabel('Elements', fontsize=14)
plt.ylabel('Operations', fontsize=14)

plt.title('Big O Notation', fontsize = 20)

plt.legend()
plt.show()
