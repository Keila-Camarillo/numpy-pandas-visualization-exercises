# %%
import env 
import pandas as pd
import numpy as np

# %%
def get_db_url(database):
    return f'mysql+pymysql://{username}:{password}@{host}/{database}'

# %%
employees_tb = pd.read_sql("select * from employees", env.get_db_url('employees'))

# %%
#Read the employees and titles tables into two separate DataFrames.

# %%
df_emp = pd.DataFrame(employees_tb)

# %%
df_emp
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles_tb = pd.read_sql("select * from titles", env.get_db_url('employees'))

# %%
titles_tb
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
df_titles = pd.DataFrame(titles_tb)

# %%
# How many rows and columns do you have in each DataFrame? Is that what you expected?
df_emp.shape
# Out:
# (300024, 6)

# %%
df_titles.shape
# Out:
# (443308, 4)

# %%
#Display the summary statistics for each DataFrame.

# %%
df_emp.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
df_titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
# How many unique titles are in the titles DataFrame?

# %%
df_titles.title.nunique()
# Out:
# 7

# %%
# What is the oldest date in the to_date column?

# %%
df_titles.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %%
# What is the most recent date in the to_date column?

# %%
df_titles.to_date.max()
# Out:
# datetime.date(9999, 1, 1)

# %%
##EXERCISE PART II
# 1. Copy the users and roles DataFrames from the examples above.
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
# 2. What is the result of using a right join on the DataFrames?
users.merge(roles, how='right', left_on='role_id', right_on='id',  indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %%
# 3. What is the result of using an outer join on the DataFrames?
users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them? only works if you merged on names only common column name
users_nk = users.drop(columns=["role_id"])

# %%
users_nk.merge(roles, how='inner', on='id', indicator=True)
# Out:
#    id name_x     name_y _merge
# 0   1    bob      admin   both
# 1   2    joe     author   both
# 2   3  sally   reviewer   both
# 3   4   adam  commenter   both

# %%
# 5. Load the mpg dataset from PyDataset.
from pydataset import data
mpg = data('mpg')
mpg = pd.DataFrame(mpg)

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
# 6. Output and read the documentation for the mpg dataset.
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
# 7. How many rows and columns are in the dataset?
mpg.shape
# Out:
# (234, 11)

# %%
# 8. Check out your column names and perform any cleanup you may want on them.
mpg.columns
mpg.drop(columns=["fl"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/bf/lhpb5n_j1xj4msxy6nrm9h7h0000gn/T/ipykernel_89116/484886423.py in <module>
#       1 # 8. Check out your column names and perform any cleanup you may want on them.
#       2 mpg.columns
# ----> 3 mpg.drop(columns=["fl"])
#       4
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
# ...

# %%
mpg = mpg.rename(columns={"cty":"city", "hwy": "highway", "class": 'cls'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26
#
#          cls  mileage_difference  average_mileage  is_automatic
# ...

# %%
# 9. Display the summary statistics for the dataset.
mpg.describe().T
# Out:
#                     count         mean       std     min     25%     50%  \
# displ               234.0     3.471795  1.291959     1.6     2.4     3.3
# year                234.0  2003.500000  4.509646  1999.0  1999.0  2003.5
# cyl                 234.0     5.888889  1.611534     4.0     4.0     6.0
# city                234.0    16.858974  4.255946     9.0    14.0    17.0
# highway             234.0    23.440171  5.954643    12.0    18.0    24.0
# mileage_difference  234.0     6.581197  2.262739     2.0     5.0     7.0
# average_mileage     234.0    20.149573  5.050290    10.5    15.5    20.5
#
#                        75%     max
# displ                  4.6     7.0
# year                2008.0  2008.0
# cyl                    8.0     8.0
# city                  19.0    35.0
# highway               27.0    44.0
# mileage_difference     8.0    12.0
# average_mileage       23.5    39.5

# %%
# 10 How many different manufacturers are there?
mpg.manufacturer.nunique()
# Out:
# 15

# %%
# 11. How many different models are there?

mpg.model.nunique()
# Out:
# 38

# %%
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.
mpg["mileage_difference"] = mpg.highway - mpg.city
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26
#
#        class  mileage_difference
# 1    compact                  11
# ...

# %%
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.
mpg["average_mileage"] = mpg[["city", "highway"]].mean(axis=1)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26
#
#        class  mileage_difference  average_mileage
# ...

# %%
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.
mpg["is_automatic"] = mpg.trans.str.contains("auto")
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26
#
#        class  mileage_difference  average_mileage  is_automatic
# ...

# %%
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?
mpg.groupby("manufacturer")["average_mileage"].mean().nlargest(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %%
# 16. Do automatic or manual cars have better miles per gallon?
mpg.groupby("is_automatic").mean().average_mileage
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64
